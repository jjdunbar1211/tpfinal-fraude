# %% [markdown]
# # 1) Cargamos los datos 📕

# %%
import pandas as pd
data = pd.read_csv("data/customer_dataset.csv", sep=',')

# %% [markdown]
# # 3) Discretización 📈➜📊

# %%
#### Vamos a hacer una copia del dataframe data para luego evaluar si los puntos de corte se guardan y leen correctamente.
probando = data.copy()

# Para `orderAmount`
data['orderAmount'], saved_bins_order = pd.qcut(
    data['orderAmount'], 
    q=5, duplicates='drop', 
    retbins=True
    )
# Guardamos los puntos de corte
import pickle
with open('data/saved_bins_order.pickle', 'wb') as handle:
    pickle.dump(saved_bins_order, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Para `transactionAmount`
data['transactionAmount'], saved_bins_order = pd.qcut(
    data['transactionAmount'], 
    q=4, duplicates='drop', 
    retbins=True
    )
# guardo
with open('data/saved_bins_transaction.pickle', 'wb') as handle:
    pickle.dump(saved_bins_order, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Vamos a evaluar que los puntos de corte / bins generado, se han guardado correctamente:
with open('data/saved_bins_order.pickle', 'rb') as handle:
    new_saved_bins_order = pickle.load(handle)
with open('data/saved_bins_transaction.pickle', 'rb') as handle:
    new_saved_bins_transaction = pickle.load(handle)

probando["orderAmount"] = pd.cut(
    probando['orderAmount'],
    bins=new_saved_bins_order, 
    include_lowest=True) # importante para que coincidan todos

probando['transactionAmount'], saved_bins_order = pd.qcut(
    probando['transactionAmount'], 
    q=4, duplicates='drop', 
    retbins=True
    )
probando.head(3)
# Out:
#      orderAmount orderState paymentMethodRegistrationFailure  \
# 0  (9.999, 18.4]    pending                             True
# 1   (18.4, 30.0]  fulfilled                             True
# 2   (39.0, 47.0]  fulfilled                            False
#
#   paymentMethodType paymentMethodProvider   paymentMethodIssuer  \
# 0              card          JCB 16 digit  Citizens First Banks
# 1           bitcoin         VISA 16 digit          Solace Banks
# 2              card         VISA 16 digit        Vertex Bancorp
#
#   transactionAmount  transactionFailed fraudulent emailDomain emailProvider  \
# 0     (9.999, 21.0]              False      False         com         yahoo
# 1      (21.0, 34.0]              False       True         com         yahoo
# 2      (34.0, 45.0]              False      False         com         yahoo
#
#   customerIPAddressSimplified sameCity
# 0                only_letters      yes
# 1                only_letters       no
# 2          digits_and_letters       no

# %%
probando["orderAmount"].unique()
# Out:
# [(9.999, 18.4], (18.4, 30.0], (39.0, 47.0], (30.0, 39.0], (47.0, 353.0], NaN]
# Categories (5, interval[float64, right]): [(9.999, 18.4] < (18.4, 30.0] < (30.0, 39.0] < (39.0, 47.0] < (47.0, 353.0]]

# %%
data["orderAmount"].unique()
# Out:
# [(9.999, 18.4], (18.4, 30.0], (39.0, 47.0], (30.0, 39.0], (47.0, 353.0], NaN]
# Categories (5, interval[float64, right]): [(9.999, 18.4] < (18.4, 30.0] < (30.0, 39.0] < (39.0, 47.0] < (47.0, 353.0]]

# %%
data['transactionAmount'].unique()
# Out:
# [(9.999, 21.0], (21.0, 34.0], (34.0, 45.0], (45.0, 353.0]]
# Categories (4, interval[float64, right]): [(9.999, 21.0] < (21.0, 34.0] < (34.0, 45.0] < (45.0, 353.0]]

# %%
probando["transactionAmount"].unique()
# Out:
# [(9.999, 21.0], (21.0, 34.0], (34.0, 45.0], (45.0, 353.0]]
# Categories (4, interval[float64, right]): [(9.999, 21.0] < (21.0, 34.0] < (34.0, 45.0] < (45.0, 353.0]]

# %% [markdown]
# # 4) Preparación de datos 🔧

# %% [markdown]
# ## 4.1) Intepretar los valores

# %% [markdown]
# ### - paymentMethodIssuer

# %%
# Contar los elementos únicos que aparecen
data['paymentMethodIssuer'].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Grand Credit Corporation    27
# Solace Banks                27
# Rose Bancshares             25
# B                            7
# e                            5
# c                            4
# r                            3
#                              2
# n                            2
# x                            2
# o                            2
# a                            1
# p                            1
# Name: count, dtype: int64

# %%
# Reemplazar un valor a la vez
weird_payment_method = ["B", "e", "c", "r", " ", "n", "x", "o", "a", "p"]
for payment_method in weird_payment_method:
    data['paymentMethodIssuer'] = data['paymentMethodIssuer'].replace(payment_method, 'weird')

data['paymentMethodIssuer'].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# weird                       29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Solace Banks                27
# Grand Credit Corporation    27
# Rose Bancshares             25
# Name: count, dtype: int64

# %% [markdown]
# ### -paymentMethodProvider

# %% [markdown]
# data['paymentMethodProvider'].value_counts()

# %% [markdown]
# ### -paymentMethodType

# %%
data['paymentMethodType'].value_counts()
from funpymodeling import status
status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                        orderAmount    145  0.232745        0  0.000000
# 1                         orderState    145  0.232745        0  0.000000
# 2   paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 3                  paymentMethodType    281  0.451043        0  0.000000
# 4              paymentMethodProvider    281  0.451043        0  0.000000
# 5                paymentMethodIssuer    281  0.451043        0  0.000000
# 6                  transactionAmount      0  0.000000        0  0.000000
# 7                  transactionFailed      0  0.000000      455  0.730337
# 8                         fraudulent    455  0.730337      107  0.171750
# 9                        emailDomain      0  0.000000        0  0.000000
# 10                     emailProvider      0  0.000000        0  0.000000
# 11       customerIPAddressSimplified      0  0.000000        0  0.000000
# 12                          sameCity      0  0.000000        0  0.000000
#
#     unique      type
# 0        5  category
# 1        3    object
# 2        2    object
# 3        4    object
# 4       10    object
# 5       11    object
# 6        4  category
# 7        2      bool
# 8        2    object
# 9        6    object
# 10       5    object
# 11       2    object
# 12       3    object

# %% [markdown]
# ### - fraudulent
# #### Vamos a hacer una especie de semáforo:
# ##### - False = Green le asignaremos el valor numérico 0
# ##### - True = Red le asignaremos el valor numérico 1
# ##### - Nan = Yellow le asignaremos el valor numérico 2

# %%
data['fraudulent']=data['fraudulent'].fillna(value="warning")
data["fraudulent"].value_counts()
# Out:
# fraudulent
# warning    455
# False      107
# True        61
# Name: count, dtype: int64

# %%
# Nos aseguramos que no exista ningún tipo de conflicto 
# por falta de compatibilidad entre str y bool de True/False.
data['fraudulent']=data['fraudulent'].astype(str)
class_map = {'False': 0, 'True': 1, 'warning': 2}
data['fraudulent'] = data['fraudulent'].map(class_map)
data.head(3)
# Out:
#      orderAmount orderState paymentMethodRegistrationFailure  \
# 0  (9.999, 18.4]    pending                             True
# 1   (18.4, 30.0]  fulfilled                             True
# 2   (39.0, 47.0]  fulfilled                            False
#
#   paymentMethodType paymentMethodProvider   paymentMethodIssuer  \
# 0              card          JCB 16 digit  Citizens First Banks
# 1           bitcoin         VISA 16 digit          Solace Banks
# 2              card         VISA 16 digit        Vertex Bancorp
#
#   transactionAmount  transactionFailed  fraudulent emailDomain emailProvider  \
# 0     (9.999, 21.0]              False           0         com         yahoo
# 1      (21.0, 34.0]              False           1         com         yahoo
# 2      (34.0, 45.0]              False           0         com         yahoo
#
#   customerIPAddressSimplified sameCity
# 0                only_letters      yes
# 1                only_letters       no
# 2          digits_and_letters       no

# %% [markdown]
# ## 4.2) Custom tratamiento de datos faltantes
# #### Lo hacemos para columnas categóricas, que en nuestro caso la única categórica con datos faltantes es `orderAmount`.

# %%
data['orderAmount'].unique()
# Out:
# [(9.999, 18.4], (18.4, 30.0], (39.0, 47.0], (30.0, 39.0], (47.0, 353.0], NaN]
# Categories (5, interval[float64, right]): [(9.999, 18.4] < (18.4, 30.0] < (30.0, 39.0] < (39.0, 47.0] < (47.0, 353.0]]

# %%
data['orderAmount']=data['orderAmount'].cat.add_categories('desconocido')
data['orderAmount']=data['orderAmount'].fillna(value='desconocido')
data['orderAmount'].unique()
# Out:
# [(9.999, 18.4], (18.4, 30.0], (39.0, 47.0], (30.0, 39.0], (47.0, 353.0], 'desconocido']
# Categories (6, object): [(9.999, 18.4] < (18.4, 30.0] < (30.0, 39.0] < (39.0, 47.0] < (47.0, 353.0] < 'desconocido']

# %% [markdown]
# # 5) One hot encoding ✂️
# ### Asigna el One hot encoding (ohe) a un nuevo dataframe llamado `data_ohe`

# %%
data_ohe = pd.get_dummies(data, dtype=int)
status(data_ohe)
# Out:
#                                              variable  q_nan  p_nan  q_zeros  \
# 0                                   transactionFailed      0    0.0      455
# 1                                          fraudulent      0    0.0      107
# 2                           orderAmount_(9.999, 18.4]      0    0.0      527
# 3                            orderAmount_(18.4, 30.0]      0    0.0      527
# 4                            orderAmount_(30.0, 39.0]      0    0.0      525
# 5                            orderAmount_(39.0, 47.0]      0    0.0      526
# 6                           orderAmount_(47.0, 353.0]      0    0.0      532
# 7                             orderAmount_desconocido      0    0.0      478
# 8                                   orderState_failed      0    0.0      573
# 9                                orderState_fulfilled      0    0.0      223
# 10                                 orderState_pending      0    0.0      595
# 11             paymentMethodRegistrationFailure_False      0    0.0      321
# 12              paymentMethodRegistrationFailure_True      0    0.0      583
# 13                        paymentMethodType_apple pay      0    0.0      587
# 14                          paymentMethodType_bitcoin      0    0.0      595
# 15                             paymentMethodType_card      0    0.0      381
# 16                           paymentMethodType_paypal      0    0.0      587
# 17             paymentMethodProvider_American Express      0    0.0      601
# 18  paymentMethodProvider_Diners Club / Carte Blanche      0    0.0      589
# 19                     paymentMethodProvider_Discover      0    0.0      598
# 20                 paymentMethodProvider_JCB 15 digit      0    0.0      603
# 21                 paymentMethodProvider_JCB 16 digit      0    0.0      558
# 22                      paymentMethodProvider_Maestro      0    0.0      591
# 23                   paymentMethodProvider_Mastercard      0    0.0      604
# 24                paymentMethodProvider_VISA 13 digit      0    0.0      591
# 25                paymentMethodProvider_VISA 16 digit      0    0.0      566
# 26                      paymentMethodProvider_Voyager      0    0.0      587
# 27                  paymentMethodIssuer_Bastion Banks      0    0.0      594
# 28            paymentMethodIssuer_Bulwark Trust Corp.      0    0.0      594
# 29           paymentMethodIssuer_Citizens First Banks      0    0.0      595
# 30        paymentMethodIssuer_Fountain Financial Inc.      0    0.0      588
# 31       paymentMethodIssuer_Grand Credit Corporation      0    0.0      596
# 32              paymentMethodIssuer_Her Majesty Trust      0    0.0      580
# 33         paymentMethodIssuer_His Majesty Bank Corp.      0    0.0      590
# 34                paymentMethodIssuer_Rose Bancshares      0    0.0      598
# 35                   paymentMethodIssuer_Solace Banks      0    0.0      596
# 36                 paymentMethodIssuer_Vertex Bancorp      0    0.0      586
# 37                          paymentMethodIssuer_weird      0    0.0      594
# 38                    transactionAmount_(9.999, 21.0]      0    0.0      456
# 39                     transactionAmount_(21.0, 34.0]      0    0.0      470
# 40                     transactionAmount_(34.0, 45.0]      0    0.0      471
# 41                    transactionAmount_(45.0, 353.0]      0    0.0      472
# 42                                    emailDomain_biz      0    0.0      612
# 43                                    emailDomain_com      0    0.0      492
# 44                                   emailDomain_info      0    0.0      617
# 45                                    emailDomain_net      0    0.0      616
# 46                                    emailDomain_org      0    0.0      614
# 47                                  emailDomain_weird      0    0.0      164
# 48                                emailProvider_gmail      0    0.0      592
# 49                              emailProvider_hotmail      0    0.0      600
# 50                                emailProvider_other      0    0.0      542
# 51                                emailProvider_weird      0    0.0      164
# 52                                emailProvider_yahoo      0    0.0      594
# 53     customerIPAddressSimplified_digits_and_letters      0    0.0      546
# 54           customerIPAddressSimplified_only_letters      0    0.0       77
# 55                                        sameCity_no      0    0.0      486
# 56                                   sameCity_unknown      0    0.0      139
# 57                                       sameCity_yes      0    0.0      621
#
#      p_zeros  unique   type
# 0   0.730337       2   bool
# 1   0.171750       3  int64
# 2   0.845907       2  int32
# 3   0.845907       2  int32
# 4   0.842697       2  int32
# 5   0.844302       2  int32
# 6   0.853933       2  int32
# 7   0.767255       2  int32
# 8   0.919743       2  int32
# 9   0.357945       2  int32
# 10  0.955056       2  int32
# 11  0.515249       2  int32
# 12  0.935795       2  int32
# 13  0.942215       2  int32
# 14  0.955056       2  int32
# 15  0.611557       2  int32
# 16  0.942215       2  int32
# 17  0.964687       2  int32
# 18  0.945425       2  int32
# 19  0.959872       2  int32
# 20  0.967897       2  int32
# 21  0.895666       2  int32
# 22  0.948636       2  int32
# 23  0.969502       2  int32
# 24  0.948636       2  int32
# 25  0.908507       2  int32
# 26  0.942215       2  int32
# 27  0.953451       2  int32
# 28  0.953451       2  int32
# 29  0.955056       2  int32
# 30  0.943820       2  int32
# 31  0.956661       2  int32
# 32  0.930979       2  int32
# 33  0.947030       2  int32
# 34  0.959872       2  int32
# 35  0.956661       2  int32
# 36  0.940610       2  int32
# 37  0.953451       2  int32
# 38  0.731942       2  int32
# 39  0.754414       2  int32
# 40  0.756019       2  int32
# 41  0.757624       2  int32
# 42  0.982343       2  int32
# 43  0.789727       2  int32
# 44  0.990369       2  int32
# 45  0.988764       2  int32
# 46  0.985554       2  int32
# 47  0.263242       2  int32
# 48  0.950241       2  int32
# 49  0.963082       2  int32
# 50  0.869984       2  int32
# 51  0.263242       2  int32
# 52  0.953451       2  int32
# 53  0.876404       2  int32
# 54  0.123596       2  int32
# 55  0.780096       2  int32
# 56  0.223114       2  int32
# 57  0.996790       2  int32

# %%
data_ohe.head(3)
# Out:
#    transactionFailed  fraudulent  orderAmount_(9.999, 18.4]  \
# 0              False           0                          1
# 1              False           1                          0
# 2              False           0                          0
#
#    orderAmount_(18.4, 30.0]  orderAmount_(30.0, 39.0]  \
# 0                         0                         0
# 1                         1                         0
# 2                         0                         0
#
#    orderAmount_(39.0, 47.0]  orderAmount_(47.0, 353.0]  \
# 0                         0                          0
# 1                         0                          0
# 2                         1                          0
#
#    orderAmount_desconocido  orderState_failed  orderState_fulfilled  ...  \
# 0                        0                  0                     0  ...
# 1                        0                  0                     1  ...
# 2                        0                  0                     1  ...
#
#    emailProvider_gmail  emailProvider_hotmail  emailProvider_other  \
# 0                    0                      0                    0
# 1                    0                      0                    0
# 2                    0                      0                    0
#
#    emailProvider_weird  emailProvider_yahoo  \
# 0                    0                    1
# 1                    0                    1
# 2                    0                    1
#
#    customerIPAddressSimplified_digits_and_letters  \
# 0                                               0
# 1                                               0
# 2                                               1
#
#    customerIPAddressSimplified_only_letters  sameCity_no  sameCity_unknown  \
# 0                                         1            0                 0
# 1                                         1            1                 0
# 2                                         0            1                 0
#
#    sameCity_yes
# 0             1
# 1             0
# 2             0
#
# [3 rows x 58 columns]

# %% [markdown]
# ### Guardar One Hot Encoding

# %%
# Hay que eliminar nuestra columna objetivo de nuestro archivo pickle.
data_ohe_without_fraudulent = data_ohe.drop(["fraudulent"], axis=1)

# %%
# Guardar el nombre de las columnas
with open('data/categories_ohe_without_fraudulent.pickle', 'wb') as handle:
    pickle.dump(data_ohe_without_fraudulent.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # 6) Guardar dataset 💾
# ### Guardamos todo el One Hot Encoding, incluyendo nuestra variable objetivo: fraudulent

# %%
filename = "data/ohe_customer_dataset.csv"
data_ohe.to_csv(filename, index = False)
